# %%
import pandas as pds

path_file = "../assets/Operaçoes.csv"

df = pds.read_csv(path_file)

display(df)
# Out:
#         Data Corretora   Ativo Operação  Quantidade   Preço Origem    Situação
# 0   21/09/20      Rico   MGLU3   Compra           4   84,90    CEI  Confirmada
# 1   01/10/20      Rico   MGLU3    Venda           3   91,44    CEI  Confirmada
# 2   01/10/20      Rico   MGLU3    Venda           3   90,50    CEI  Confirmada
# 3   18/11/20      Rico   MGLU3   Compra          10   24,57    CEI  Confirmada
# 4   30/11/20      Rico   ITSA4   Compra           3   10,85    CEI  Confirmada
# 5   07/12/20      Rico   MGLU3   Compra           4   24,12    CEI  Confirmada
# 6   07/12/20      Rico   MGLU3   Compra           3   24,12    CEI  Confirmada
# 7   11/12/20      Rico   MGLU3   Compra           5   22,98    CEI  Confirmada
# 8   04/01/21      Rico   ITSA4   Compra          10   11,54    CEI  Confirmada
# 9   20/01/21      Rico   ENBR3   Compra           3   20,19    CEI  Confirmada
# 10  21/01/21      Rico   ITSA4   Compra           6   11,29    CEI  Confirmada
# ...
